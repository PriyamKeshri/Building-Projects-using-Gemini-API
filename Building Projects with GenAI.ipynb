# %% [markdown]
# ## Install the Python SDK
#
# The Python SDK for the Gemini API, is contained in the `google-generativeai` package

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# ## Import packages
#
# Import the necessary packages

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
GOOGLE_API_KEY= userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## List models

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %% [markdown]
# ## Generate text from text inputs

# %%
model = genai.GenerativeModel('gemini-3.6-flash')

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-3.6-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
# %%time
response = model.generate_content("How can one use Gemini to create end-to-end projects")
# Out:
# CPU times: user 109 ms, sys: 11 ms, total: 120 ms
# Wall time: 16.7 s

# %%
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "Using Gemini to build an end-to-end project\u2014whether it\u2019s a web application, a data analysis pipeline, or a marketing campaign\u2014requires leveraging it as a **copilot across the entire lifecycle** of the project. \n\nBecause of Gemini 1.5 Pro\u2019s **massive context window** (up to 2 million tokens) and **multimodal capabilities** (ability to read code, text, images, video, and audio), it is uniquely suited for managing large, complex builds.\n\nHere is a step-by-step blueprint for using Gemini to execute an end-to-end project.\n\n---\n\n### Phase 1: Ideation, Planning & Architecture\nBefore writing code or creating content, use Gemini to structure the project.\n\n1. **Define the Scope & Generate a PRD (Product Requirement Document):**\n   * *Prompt Example:* \"I want to build a SaaS tool that uses AI to summarize long PDF contracts for real estate agents. Act as a Senior Product Manager and draft a full Product Requirement Document (PRD) including user personas, core features, MVP scope, and success metrics.\"\n2. **Choose the Tech Stack / Strategy:**\n   * Ask Gemini to recommend tools based on your skills: \"I know Python and basic React. What tech stack should I use for this project to ensure low cost and fast deployment?\"\n3. **Design the Architecture:**\n   * Ask Gemini to draft system diagrams (in Mermaid.js format) or database schemas.\n   * *Prompt Example:* \"Generate a PostgreSQL database schema for an e-commerce store with users, products, orders, and inventory. Output the SQL DDL commands.\"\n\n---\n\n### Phase 2: Design & Prototyping\nGemini\u2019s multimodal capabilities shine here.\n\n1. **Sketch to Code (UI/UX):**\n   * Hand-draw a wireframe of your UI on paper, take a picture, and upload it to Gemini.\n   * *Prompt:* \"Convert this sketch of a dashboard into responsive HTML and Tailwind CSS code.\"\n2. **API & Data Flow Design:**\n   * Ask Gemini to design your backend API endpoints (REST or GraphQL).\n   * *Prompt:* \"Write the Swagger/OpenAPI specification for the backend of a task management app.\"\n\n---\n\n### Phase 3: Development & Implementation\nThis is the build phase. For coding projects, using **Google AI Studio** (which uses Gemini 1.5 Pro) is often better than the standard chat interface because it has a higher context window and allows system instructions.\n\n1. **Generate Boilerplate Code:**\n   * Ask Gemini to generate the initial directory structure and config files (`package.json`, `Dockerfile`, `.env.example`).\n2. **Iterative Code Generation:**\n   * Build module by module rather than asking for the whole app at once.\n   * *Example:* First, ask for the database connection file, then the authentication middleware, then the API routes.\n3. **Utilize the Massive Context Window:**\n   * If you get stuck, you can upload your **entire codebase** (e.g., as a `.zip` or concatenated `.txt` file) into Gemini 1.5 Pro.\n   * *Prompt:* \"Here is my full project repository. Add a dark mode feature across all components while adhering to the existing coding style.\"\n\n---\n\n### Phase 4: Testing, Debugging & QA\n\n1. **Automated Error Debugging:**\n   * Copy and paste terminal errors, stack traces, or broken code.\n   * *Prompt:* \"My Node.js backend crashes with this error: `[Paste Stack Trace]`. Here is my `server.js` file. Identify the bug and provide the corrected code.\"\n2. **Generate Test Suites:**\n   * Ask Gemini to write unit and integration tests for your code.\n   * *Prompt:* \"Write Jest unit tests for the following React component, covering edge cases like network failures and empty states.\"\n3. **Security & Performance Audits:**\n   * *Prompt:* \"Review this SQL query/API endpoint for security vulnerabilities (like SQL injection or XSS) and suggest performance optimizations.\"\n\n---\n\n### Phase 5: Deployment & Documentation\n\n1. **Infrastructure as Code (IaC):**\n   * Ask Gemini to write setup scripts or deployment configurations.\n   * *Prompt: ...
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 14,
#         "candidates_token_count": 1369,
#         "total_token_count": 2411
#       },
#       "model_version": "gemini-3.6-flash"
#     }),
# )

# %% [markdown]
# If the API failed to return a result, use `GenerateContentResponse.prompt_feedback` to see if it was blocked due to safety concerns regarding the prompt.

# %%
response.prompt_feedback
